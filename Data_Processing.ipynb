# %% [markdown]
# #Data Processing, Transformation, Manipulation

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("D:\Work Station\Scraper\QS World University Rankings 2023.csv", index_col = 0)

# %%
df.index = np.arange(1, len(df)+1)

# %%
df.head()
# Out:
#   World Rank                              University Name  \
# 1          1  Massachusetts Institute of Technology (MIT)
# 2          2                      University of Cambridge
# 3          3                          Stanford University
# 4          4                         University of Oxford
# 5          5                           Harvard University
#
#                      Country Overall Score Academic Reputation  \
# 1   Cambridge, United States           100                 100
# 2  Cambridge, United Kingdom          98.8                 100
# 3    Stanford, United States          98.5                 100
# 4     Oxford, United Kingdom          98.4                 100
# 5   Cambridge, United States          97.6                 100
#
#   Employer Reputation Citations per Faculty Faculty Students Ratio  \
# 1                 100                   100                    100
# 2                 100                  92.3                    100
# ...

# %%
df.shape
# Out:
# (1424, 12)

# %%
df.isnull().sum()
# Out:
# World Rank                        0
# University Name                   0
# Country                           0
# Overall Score                     0
# Academic Reputation               0
# Employer Reputation               0
# Citations per Faculty             0
# Faculty Students Ratio            0
# International Students Ratio      0
# International Faculty Ratio       0
# International Research Network    0
# Employment Outcomes               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1424 entries, 1 to 1424
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   World Rank                      1424 non-null   object
#  1   University Name                 1424 non-null   object
#  2   Country                         1424 non-null   object
#  3   Overall Score                   1424 non-null   object
#  4   Academic Reputation             1424 non-null   object
#  5   Employer Reputation             1424 non-null   object
#  6   Citations per Faculty           1424 non-null   object
#  7   Faculty Students Ratio          1424 non-null   object
#  8   International Students Ratio    1424 non-null   object
#  9   International Faculty Ratio     1424 non-null   object
#  10  International Research Network  1424 non-null   object
#  11  Employment Outcomes             1424 non-null   object
# dtypes: object(12)
# ...

# %%
df['World Rank'] = df['World Rank'].map(lambda x: x.lstrip('='))
df.tail(10)
# Out:
#      World Rank                                   University Name  \
# 1415      1401+                    Universidad Mayor de San Simón
# 1416      1401+             Universidad de San Nicolás de Hidalgo
# 1417      1401+  Universidad Nacional Autónoma de Honduras (UNAH)
# 1418      1401+                Universidad Tecnológica de Bolívar
# 1419      1401+                           Universidad de Tarapaca
# 1420      1401+                             University of Craiova
# 1421      1401+                              University of Oradea
# 1422      1401+                    Université Mohammed V de Rabat
# 1423      1401+                              University of Oradea
# 1424      1401+                    Université Mohammed V de Rabat
#
#                     Country Overall Score Academic Reputation  \
# 1415    Cochabamba, Bolivia             -                 3.6
# 1416        Morelia, Mexico             -                 3.4
# ...

# %%
new_cols = ['World Rank',
 'University Name',
 'State',
 'Country',
 'Overall Score',
 'Academic Reputation',
 'Employer Reputation',
 'Citations per Faculty',
 'Faculty Students Ratio',
 'International Students Ratio',
 'International Faculty Ratio',
 'International Research Network',
 'Employment Outcomes'
 ]
# Out:
# ['World Rank',
#  'University Name',
#  'State',
#  'Country',
#  'Overall Score',
#  'Academic Reputation',
#  'Employer Reputation',
#  'Citations per Faculty',
#  'Faculty Students Ratio',
#  'International Students Ratio',
#  'International Faculty Ratio',
#  'International Research Network',
#  'Employment Outcomes']

# %%
df['State'] = df['Country'].str.split(',').apply(lambda x: x[0])
df['Country'] = df['Country'].str.split(',').apply(lambda x: x[-1])
df=df.reindex(columns= new_cols)
df
# Out:
#      World Rank                              University Name      State  \
# 1             1  Massachusetts Institute of Technology (MIT)  Cambridge
# 2             2                      University of Cambridge  Cambridge
# 3             3                          Stanford University   Stanford
# 4             4                         University of Oxford     Oxford
# 5             5                           Harvard University  Cambridge
# ...         ...                                          ...        ...
# 1420      1401+                        University of Craiova    Craiova
# 1421      1401+                         University of Oradea     Oradea
# 1422      1401+               Université Mohammed V de Rabat      Rabat
# 1423      1401+                         University of Oradea     Oradea
# 1424      1401+               Université Mohammed V de Rabat      Rabat
#
#               Country  Overall Score  Academic Reputation  \
# ...

# %%
columns = ['Overall Score', 'Academic Reputation','Employer Reputation', 'Citations per Faculty', 'Faculty Students Ratio', 'International Students Ratio', 'International Faculty Ratio', 'International Research Network', 'Employment Outcomes']
df[columns] =df[columns].replace('-', '0')
df[columns] =df[columns].replace('QS Stars', '0.0')
df[columns]=df[columns].apply(pd.to_numeric)
df['Country'] = df['Country'].replace('5', '')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1424 entries, 1 to 1424
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   World Rank                      1424 non-null   object
#  1   University Name                 1424 non-null   object
#  2   State                           1424 non-null   object
#  3   Country                         1424 non-null   object
#  4   Overall Score                   1424 non-null   float64
#  5   Academic Reputation             1424 non-null   float64
#  6   Employer Reputation             1424 non-null   float64
#  7   Citations per Faculty           1424 non-null   float64
#  8   Faculty Students Ratio          1424 non-null   float64
#  9   International Students Ratio    1424 non-null   float64
#  10  International Faculty Ratio     1424 non-null   float64
#  11  International Research Network  1424 non-null   float64
# ...

# %%
df.tail()
# Out:
#      World Rank                 University Name    State           Country  \
# 1420      1401+           University of Craiova  Craiova  Craiova, Romania
# 1421      1401+            University of Oradea   Oradea   Oradea, Romania
# 1422      1401+  Université Mohammed V de Rabat    Rabat    Rabat, Morocco
# 1423      1401+            University of Oradea   Oradea   Oradea, Romania
# 1424      1401+  Université Mohammed V de Rabat    Rabat    Rabat, Morocco
#
#       Overall Score  Academic Reputation  Employer Reputation  \
# 1420            0.0                  3.3                  1.8
# 1421            0.0                  4.0                  2.1
# 1422            0.0                  2.8                  2.6
# 1423            0.0                  4.0                  2.1
# 1424            0.0                  2.8                  2.6
#
#       Citations per Faculty  Faculty Students Ratio  \
# 1420                    2.0                     2.7
# ...

# %%
df.to_csv("D:\Work Station\Scraper\QS World University Rankings 2023 modified.csv")
